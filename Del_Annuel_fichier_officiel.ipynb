# %% [markdown]
# # Group Work
# + Souleymane DIALLO
# + Ndeye Issa KA
# + Tacko NDIAYE

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
os.chdir("C:\\UAM\\Semestre3\\Informatique_4\\DataScience\\Doc_chap2")

# %%
r = pd.read_excel("Del_Annuel.xlsx", engine = "openpyxl")
r
# Out:
#    Unnamed: 0 Université Amadou Mahtar MBOW  \
# 0         NaN                           NaN
# 1         NaN                           NaN
# 2         NaN                           NaN
# 3         NaN                           NaN
# 4         NaN                           NaN
# 5         NaN                           NaN
# 6         NaN                           NaN
# 7         NaN                           NaN
# 8         NaN                           NaN
# 9        C.P.                           Nom
# 10        NaN                           NaN
# 11     100234                    BAKHAYOKHO
# 12     100121                         BALDE
# 13     100300                          BOYE
# 14     100308                       DASYLVA
# 15     100334                          DIA
# 16     100329                        DIALLO
# 17     100320                        DIALLO
# 18     100319                       DIAKHAM
# 19     100327                          DIAW
# ...

# %%
r.iloc[9,:]
# Out:
# Unnamed: 0                                      C.P.
# Université Amadou Mahtar MBOW                    Nom
# Unnamed: 2                                    Prénom
# Unnamed: 3                         Date de Naissance
# Unnamed: 4                                  Chimie 1
# Unnamed: 5                                  Chimie 2
# Unnamed: 6                            Informatique 1
# Unnamed: 7                            Informatique 2
# Unnamed: 8                           Mathématiques 1
# Unnamed: 9                           Mathématiques 2
# Unnamed: 10                         Outils de base 1
# Unnamed: 11                         Outils de base 2
# Unnamed: 12                               Physique 1
# Unnamed: 13                               Physique 2
# Unnamed: 14                      Sciences Graphiques
# Unnamed: 15                                 RESULTAT
# Unnamed: 16                                      NaN
# Name: 9, dtype: object

# %%
Index_lignes = r[r["Université Amadou Mahtar MBOW"] == "NaN"].index
r.drop(Index_lignes, inplace = True)

# %%
new = r.dropna()
#newTab = new
new
# Out:
#    Unnamed: 0 Université Amadou Mahtar MBOW      Unnamed: 2  Unnamed: 3  \
# 11     100234                    BAKHAYOKHO          Moussa  30/03/1998
# 12     100121                         BALDE          Amadou  21/01/2002
# 13     100300                          BOYE        Ibrahima  26/11/2001
# 14     100308                       DASYLVA            Jean  11/11/1999
# 15     100334                          DIA           Oumar   04/03/2000
# 16     100329                        DIALLO       Fatimatou  15/11/2001
# 17     100320                        DIALLO       Abdoulaye  26/03/1999
# 18     100319                       DIAKHAM      Mouhamadou  18/12/1999
# 19     100327                          DIAW     Pape Moussa  01/04/2002
# 20     100311                        DIAGNE         Aminata  11/03/2000
# 21     100299                          DIOP         Babacar  18/12/2000
# 22     100335                          DIOP         Ismaila  30/09/2000
# ...

# %%
titre = r.iloc[9,:].values
print("len : ", len(titre))
titre
# Out:
# len :  17
# array(['C.P.', 'Nom', 'Prénom', 'Date de Naissance', 'Chimie 1',
#        'Chimie 2', 'Informatique 1', 'Informatique 2', 'Mathématiques 1',
#        'Mathématiques 2', 'Outils de base 1', 'Outils de base 2',
#        'Physique 1', 'Physique 2', 'Sciences Graphiques', 'RESULTAT', nan],
#       dtype=object)

# %%
col = new.columns
new
# Out:
#    Unnamed: 0 Université Amadou Mahtar MBOW      Unnamed: 2  Unnamed: 3  \
# 11     100234                    BAKHAYOKHO          Moussa  30/03/1998
# 12     100121                         BALDE          Amadou  21/01/2002
# 13     100300                          BOYE        Ibrahima  26/11/2001
# 14     100308                       DASYLVA            Jean  11/11/1999
# 15     100334                          DIA           Oumar   04/03/2000
# 16     100329                        DIALLO       Fatimatou  15/11/2001
# 17     100320                        DIALLO       Abdoulaye  26/03/1999
# 18     100319                       DIAKHAM      Mouhamadou  18/12/1999
# 19     100327                          DIAW     Pape Moussa  01/04/2002
# 20     100311                        DIAGNE         Aminata  11/03/2000
# 21     100299                          DIOP         Babacar  18/12/2000
# 22     100335                          DIOP         Ismaila  30/09/2000
# ...

# %%
new.columns = titre
new
# Out:
#       C.P.         Nom          Prénom Date de Naissance Chimie 1 Chimie 2  \
# 11  100234  BAKHAYOKHO          Moussa        30/03/1998        7        0
# 12  100121       BALDE          Amadou        21/01/2002        7        6
# 13  100300        BOYE        Ibrahima        26/11/2001        7        0
# 14  100308     DASYLVA            Jean        11/11/1999        7        6
# 15  100334        DIA           Oumar         04/03/2000        7        6
# 16  100329      DIALLO       Fatimatou        15/11/2001        7        0
# 17  100320      DIALLO       Abdoulaye        26/03/1999        7        6
# 18  100319     DIAKHAM      Mouhamadou        18/12/1999        7        6
# 19  100327        DIAW     Pape Moussa        01/04/2002        7        6
# 20  100311      DIAGNE         Aminata        11/03/2000        7        0
# 21  100299        DIOP         Babacar        18/12/2000        7        6
# ...

# %%
"""#Autre methode...****************
col = new.columns
newCol = ["CP", "Nom", "Prenom","DateNaissance","Chimie1","Chimie2","Info1","Info2",
          "Math1","Math2", "OutilsBase1", "OutilsBase2","Physique1","Physique2",
          "SciencesGraphique","TotalCredit", "Resultats"]
#for i in range(len(col)):
#    new.columns[i] = newCol[i]

new.columns = newCol
new"""
# Out:
# '#Autre methode...****************\ncol = new.columns\nnewCol = ["CP", "Nom", "Prenom","DateNaissance","Chimie1","Chimie2","Info1","Info2",\n          "Math1","Math2", "OutilsBase1", "OutilsBase2","Physique1","Physique2",\n          "SciencesGraphique","TotalCredit", "Resultats"]\n#for i in range(len(col)):\n#    new.columns[i] = newCol[i]\n\nnew.columns = newCol\nnew'

# %%
new.reset_index(drop = True)
# Out:
#       C.P.         Nom          Prénom Date de Naissance Chimie 1 Chimie 2  \
# 0   100234  BAKHAYOKHO          Moussa        30/03/1998        7        0
# 1   100121       BALDE          Amadou        21/01/2002        7        6
# 2   100300        BOYE        Ibrahima        26/11/2001        7        0
# 3   100308     DASYLVA            Jean        11/11/1999        7        6
# 4   100334        DIA           Oumar         04/03/2000        7        6
# 5   100329      DIALLO       Fatimatou        15/11/2001        7        0
# 6   100320      DIALLO       Abdoulaye        26/03/1999        7        6
# 7   100319     DIAKHAM      Mouhamadou        18/12/1999        7        6
# 8   100327        DIAW     Pape Moussa        01/04/2002        7        6
# 9   100311      DIAGNE         Aminata        11/03/2000        7        0
# 10  100299        DIOP         Babacar        18/12/2000        7        6
# ...

# %%
tri = new.sort_values(by = ["RESULTAT", "Nom", "Prénom"], ascending = [False, True, True])
tri.reset_index(drop = True)
# Out:
#       C.P.         Nom          Prénom Date de Naissance Chimie 1 Chimie 2  \
# 0   100121       BALDE          Amadou        21/01/2002        7        6
# 1   100308     DASYLVA            Jean        11/11/1999        7        6
# 2   100334        DIA           Oumar         04/03/2000        7        6
# 3   100319     DIAKHAM      Mouhamadou        18/12/1999        7        6
# 4   100320      DIALLO       Abdoulaye        26/03/1999        7        6
# 5   100327        DIAW     Pape Moussa        01/04/2002        7        6
# 6   100316        DIOP             Awa        05/07/2001        7        6
# 7   100299        DIOP         Babacar        18/12/2000        7        6
# 8   100335        DIOP         Ismaila        30/09/2000        7        6
# 9   100328        DIOP         Olimata        10/05/2002        7        6
# 10  100301        FALL        Aissatou        27/12/2001        7        6
# ...

# %%
tri.rename(columns = {"RESULTAT" : "Total Credit"}, inplace = True)
#tri.rename(columns = {"nan" : "RESULTAT"}, inplace = True)
tri
# Out:
#       C.P.         Nom          Prénom Date de Naissance Chimie 1 Chimie 2  \
# 12  100121       BALDE          Amadou        21/01/2002        7        6
# 14  100308     DASYLVA            Jean        11/11/1999        7        6
# 15  100334        DIA           Oumar         04/03/2000        7        6
# 18  100319     DIAKHAM      Mouhamadou        18/12/1999        7        6
# 17  100320      DIALLO       Abdoulaye        26/03/1999        7        6
# 19  100327        DIAW     Pape Moussa        01/04/2002        7        6
# 25  100316        DIOP             Awa        05/07/2001        7        6
# 21  100299        DIOP         Babacar        18/12/2000        7        6
# 22  100335        DIOP         Ismaila        30/09/2000        7        6
# 23  100328        DIOP         Olimata        10/05/2002        7        6
# 27  100301        FALL        Aissatou        27/12/2001        7        6
# ...

# %%
tri.columns = tri.columns.fillna("Decision") # Rename nan name_column

# %%
result = pd.ExcelWriter("deliberation_UAM_L1.xlsx", engine = "xlsxwriter")
tri.to_excel(result, "Resultats_Annuels", index = False)
result.save()

# %%
tri
# Out:
#       C.P.         Nom          Prénom Date de Naissance Chimie 1 Chimie 2  \
# 12  100121       BALDE          Amadou        21/01/2002        7        6
# 14  100308     DASYLVA            Jean        11/11/1999        7        6
# 15  100334        DIA           Oumar         04/03/2000        7        6
# 18  100319     DIAKHAM      Mouhamadou        18/12/1999        7        6
# 17  100320      DIALLO       Abdoulaye        26/03/1999        7        6
# 19  100327        DIAW     Pape Moussa        01/04/2002        7        6
# 25  100316        DIOP             Awa        05/07/2001        7        6
# 21  100299        DIOP         Babacar        18/12/2000        7        6
# 22  100335        DIOP         Ismaila        30/09/2000        7        6
# 23  100328        DIOP         Olimata        10/05/2002        7        6
# 27  100301        FALL        Aissatou        27/12/2001        7        6
# ...

# %%
res = tri.Decision.value_counts()
tot = {"Total" : sum(res.values)}
res.update(tot)
res
# Out:
# Passage Définitif       27
# Redouble                11
# Passage Conditionnel     6
# Exclu                    1
# Name: Decision, dtype: int64

# %%
nbre = tri.Decision.value_counts().values
nbre
# Out:
# array([27, 11,  6,  1], dtype=int64)

# %%
p = np.round(nbre*100/ (sum(nbre)), 1)
p
sum(p)
p
# Out:
# array([60. , 24.4, 13.3,  2.2])

# %%
p
p1 = [] # Vecteur modulo
for x in p:
    p1.append(round(x,1) - round(x))
p1
#round(p[1],1)
#ound(p[1])
maxp1 = max(p1)

i = p1.index(maxp1)
i
p[i] +=  0.1
p[i]
sum(p),p
# Out:
# (100.0, array([60. , 24.5, 13.3,  2.2]))

# %%
df = pd.DataFrame(res)
df.rename(columns = {"Decision" : "Nombre d'etudiants"}, inplace = True)
df.columns
df
# Out:
#                       Nombre d'etudiants
# Passage Définitif                     27
# Redouble                              11
# Passage Conditionnel                   6
# Exclu                                  1

# %%
#insertion colonne pourcentage ****************
if "Pourcentage" in df.columns:
    del df["Pourcentage"]
    df.insert(1, "Pourcentage", p, allow_duplicates = False)
else:
    df.insert(1, "Pourcentage", p, allow_duplicates = False)
df
# Out:
#                       Nombre d'etudiants  Pourcentage
# Passage Définitif                     27         60.0
# Redouble                              11         24.5
# Passage Conditionnel                   6         13.3
# Exclu                                  1          2.2

# %%
#Insertion derniere ligne du Dataframe ***************
df.loc["Total"] = [sum(res), sum(p)]
df
# Out:
#                       Nombre d'etudiants  Pourcentage
# Passage Définitif                   27.0         60.0
# Redouble                            11.0         24.5
# Passage Conditionnel                 6.0         13.3
# Exclu                                1.0          2.2
# Total                               45.0        100.0

# %%
labels = df.iloc[:4,0]
labels = labels.index
labels,p
# Out:
# (Index(['Passage Définitif', 'Redouble', 'Passage Conditionnel', 'Exclu'], dtype='object'),
#  array([60. , 24.5, 13.3,  2.2]))

# %%
# Diagramme circulaire
df.index
serie = p
sep = (0,0,0,0)
fig,ax = plt.subplots(figsize = (10,6))
ax.pie(serie, explode = sep, labels = labels, autopct = "%1.0f%%", shadow = True, startangle = 0)
ax.axis('equal')
plt.show()

# %%
# To excel
import xlwings as xw
result1 = pd.ExcelWriter("deliberation_UAM_L1.xlsx", engine = "openpyxl", mode = "a")
df.to_excel(result1, "Stats", index = False)
result1.save()

# %%
result2 = xw.Book("deliberation_UAM_L1.xlsx")
#result2.sheets.add("Stats1")
feuille = result2.sheets("Stats")
ax = ax.get_figure()
feuille.pictures.add(ax, name = "Stats", update = True)
plt.show()
